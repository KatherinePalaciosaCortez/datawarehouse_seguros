# %% [markdown]
# <a href="https://colab.research.google.com/github/KatherinePalaciosaCortez/datawarehouse_seguros/blob/main/Te_damos_la_bienvenida_a_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://github.com/KatherinePalaciosaCortez/datawarehouse_seguros.git

# %%
import pandas as pd

# %%
#ruta del dataset almacenado en git
url = "https://raw.githubusercontent.com/KatherinePalaciosaCortez/datawarehouse_seguros/refs/heads/main/clientes.csv"

# %%
df = pd.read_csv(url)
print("Dataset Cargado corrextamente")
# Out:
# Dataset Cargado corrextamente

# %%
display(df.head())
# Out:
#    id_cliente                 nombre                             email  \
# 0           1      José Chávez Pérez      jose.chavez.perez1@gmail.com
# 1           2    Daniela Rojas Ortiz    daniela.rojas.ortiz2@seguro.sv
# 2           3    Ricardo Cruz Flores  ricardo.cruz.flores3@example.com
# 3           4      María Pérez Pérez     maria.perez.perez4@correo.com
# 4           5  Fernanda Chávez Rojas  fernanda.chavez.rojas5@seguro.sv
#
#       genero fecha_nacimiento          ciudad segmento
# 0     Hombre       2011/11/24       SanMiguel      NaN
# 1        NaN         01-02-80        Sta. Ana      NaN
# 2  Masculino         06-18-79       S. Miguel      NaN
# 3  Masculino       1960-09-29      LaLibertad  REGULAR
# 4        NaN       1945/08/02   San Salvador      Pyme

# %% [markdown]
# BLOQUE 2:Exploracion del DATASET

# %%
print("primeras filas del dataset")
display(df.head())
# Out:
# primeras filas del dataset
#    id_cliente                 nombre                             email  \
# 0           1      José Chávez Pérez      jose.chavez.perez1@gmail.com
# 1           2    Daniela Rojas Ortiz    daniela.rojas.ortiz2@seguro.sv
# 2           3    Ricardo Cruz Flores  ricardo.cruz.flores3@example.com
# 3           4      María Pérez Pérez     maria.perez.perez4@correo.com
# 4           5  Fernanda Chávez Rojas  fernanda.chavez.rojas5@seguro.sv
#
#       genero fecha_nacimiento          ciudad segmento
# 0     Hombre       2011/11/24       SanMiguel      NaN
# 1        NaN         01-02-80        Sta. Ana      NaN
# 2  Masculino         06-18-79       S. Miguel      NaN
# 3  Masculino       1960-09-29      LaLibertad  REGULAR
# 4        NaN       1945/08/02   San Salvador      Pyme

# %%
print("Disemensiones del dataset(filas,coloumnas)")
print(df.shape)
# Out:
# Disemensiones del dataset(filas,coloumnas)
# (3030, 7)

# %%
print("columnas del dataset")
print(df.columns)
# Out:
# columnas del dataset
# Index(['id_cliente', 'nombre', 'email', 'genero', 'fecha_nacimiento', 'ciudad',
#        'segmento'],
#       dtype='object')

# %%
print("tipo de datos")
print(df.dtypes)
# Out:
# tipo de datos
# id_cliente           int64
# nombre              object
# email               object
# genero              object
# fecha_nacimiento    object
# ciudad              object
# segmento            object
# dtype: object

# %%
print("valorees nulos por columna")
print(df.isnull().sum())
# Out:
# valorees nulos por columna
# id_cliente            0
# nombre                0
# email                 0
# genero              595
# fecha_nacimiento      0
# ciudad                0
# segmento            597
# dtype: int64

# %%
print("Registros duplicados")
print(df.duplicated().sum())
# Out:
# Registros duplicados
# 0

# %% [markdown]
# BLOQUE 3: LIMPIEZA DE DATOS

# %%
#ELIMINA ESPACIOS AL INICO Y AL FINAL E COLUMNAS DE TEXTO
for col in df.select_dtypes(include="object").columns:df[col]=df[col].str.strip()

# %%
#Normalizar el nombre
df["nombre"]=df["nombre"].str.title()

# %%
#Normalizar el email
df["email"]=df["email"].str.lower()

# %%
#Normalizar el genero
df["genero"]=df["genero"].str.upper()

# %%
#Convertir fecha de nacimiento a formato fecha
df['fecha_nacimiento']=pd.to_datetime(df['fecha_nacimiento'],errors="coerce")

# %%
#normalizar ciudad
df["ciudad"]=df['ciudad'].str.title()

# %%
#normalizar Ciudad
df['ciudad']=df['ciudad'].str.title()
df['ciudad']=df['ciudad'].astype(str)
df['ciudad']=df['ciudad'].str.upper()

# %%
#normalizar segmento
df['segmento']=df['segmento'].astype(str)
df['segmento']=df['segmento'].str.strip()
df['segmento']=df['segmento'].str.upper()

# %%
from os import EX_TEMPFAIL
from enum import nonmember
for col in df.columns: print(col)
# Out:
# id_cliente
# nombre
# email
# genero
# fecha_nacimiento
# ciudad
# segmento

# %% [markdown]
# BLOQUE 4: VALIDACION DE DATOS

# %%
#crear columna para registrar errores
df["motivo_rechazo"]=""

#validar id clientw
df.loc[df["id_cliente"].isnull(),"motivo_rechazo"]="id_cliente nulo;"
